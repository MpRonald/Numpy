# %% [markdown]
# # Variáveis

# %%
a = 3

# %%
print(a)
# Out:
# 3

# %%
b = 2

# %%
print(a + b)
# Out:
# 5

# %%
print(a - b)
# Out:
# 1

# %%
d = 4

# %%
print(a + d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3d3962cda73c> in <module>
# ----> 1 print(a + d)
#
# NameError: name 'd' is not defined

# %%
int('2') + int('3')
# Out:
# 5

# %%
a, b, c = 1, 2, 3

# %%
print(a, b, c)
# Out:
# 1 2 3

# %%
print(a + b + c)
# Out:
# 6

# %%
i = 10.30

# %%
type(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a1e13ff1610c> in <module>
# ----> 1 type(i)
#
# NameError: name 'i' is not defined

# %%
print(10 + 10)
# Out:
# 20

# %%
if True:
    a == 10
    print(a)
# Out:
# 1
